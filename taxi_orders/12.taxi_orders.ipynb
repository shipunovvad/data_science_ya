# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor 
import catboost as cb

from sklearn.model_selection import cross_val_score, GridSearchCV , train_test_split, TimeSeriesSplit 

from sklearn.metrics import make_scorer, mean_squared_error 

RS=42

# %%
df = pd.read_csv('/datasets/taxi.csv',index_col=[0], parse_dates=[0])

# %%
#Проверим в даты на хронологический порядок
df.index.is_monotonic
# Out:
# True

# %%
df.sample(5)
# Out:
#                      num_orders
# datetime
# 2018-08-03 02:20:00          26
# 2018-07-26 22:10:00          20
# 2018-05-20 10:40:00          14
# 2018-03-07 04:20:00           8
# 2018-05-22 13:30:00           8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
df.isna().sum()
# Out:
# num_orders    0
# dtype: int64

# %%
# ресемплирование по одному часу.
df=df.resample('1H').sum()

# %%
df.plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# **Вывод по главе**
#
# - Исходный датасет состоит из 2 столбцов:
#
#     -  datetime — дата и время заказа
#     -  num_orders — количество заказов.
#
# - Количество строк в датасете 26_496.
#
# - Данные были ресемплированы.

# %% [markdown]
# ## Анализ

# %%
print('Starting date:',df.index.min())
print('Ending date:',df.index.max())
print('Total time:',df.index.max() - df.index.min())
print('////_______________________________________//////_________________________________________///')
df.describe()
# Out:
# Starting date: 2018-03-01 00:00:00
# Ending date: 2018-08-31 23:00:00
# Total time: 183 days 23:00:00
# ////_______________________________________//////_________________________________________///
#         num_orders
# count  4416.000000
# mean     84.422781
# std      45.023853
# min       0.000000
# 25%      54.000000
# 50%      78.000000
# 75%     107.000000
# max     462.000000

# %% [markdown]
# Данные собраны за 184 дня. Минимальное количество заказов за 1 час -  0, а максимальное -119.

# %%
 #график вызовов по дням
df.resample('1D').sum().plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
#скользящая средняя 10
df.resample('1D').sum().rolling(10).mean().plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Виден восхдящий тренд

# %%
# Анализ временного ряда
decomposed = seasonal_decompose(df)

plt.figure(figsize=(12, 15))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca()) # < напишите код здесь >
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca()) # < напишите код здесь >
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# Не очень информативная картинка

# %%
# Анализ временного ряда с семплированием до 1 дня
decomposed = seasonal_decompose(df.resample('1D').sum())

plt.figure(figsize=(12, 15))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca()) # < напишите код здесь >
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca()) # < напишите код здесь >
plt.title('Residuals')
plt.tight_layout()

# %%
dw=df.copy()
dw['dayofweek'] = dw.index.dayofweek
dw.groupby('dayofweek')['num_orders'].mean().plot(figsize=(12, 7))
# Out:
# <AxesSubplot:xlabel='dayofweek'>

# %% [markdown]
# На графике отчетливо видна зависитмость количества заказов от дня недели. Активно пользуются такси в начале и конце рабочей недели. В выходные количество заказов идет на спад.

# %%
#Посмотрим данные за неделю

decomposed = seasonal_decompose(df['2018-08-14':'2018-08-20'].resample('1H').sum())

plt.figure(figsize=(12, 20))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')

plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')

plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# Аналогичной зависимости не видно.

# %% [markdown]
# **Вывод по Главе**
#
#
#  - Выявлен тренд на общее увеличение заказов такси
#  - Существует зависитмость количества заказов от дня недели

# %% [markdown]
# ## Обучение

# %% [markdown]
# В качестве моделей используем Линейную регрессию, Случайный лес и CatBoostRegressor.

# %%
# Используем функцию для создания признаков,которая была написана в курсе
def make_features(dt, max_lag, rolling_mean_size):
    data = dt.copy()
    data['year'] = data.index.year
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    data = data.dropna()
    return data

# %%
#Применим функцию с лагом до 24 часов и 100-м скользящим средним:
df = make_features(df, 24, 100)

# %%
df = df.dropna()

# %%
df.head()
# Out:
#                      num_orders  year  month  day  dayofweek  lag_1  lag_2  \
# datetime
# 2018-03-05 04:00:00          34  2018      3    5          0   51.0   32.0
# 2018-03-05 05:00:00          16  2018      3    5          0   34.0   51.0
# 2018-03-05 06:00:00           3  2018      3    5          0   16.0   34.0
# 2018-03-05 07:00:00          14  2018      3    5          0    3.0   16.0
# 2018-03-05 08:00:00          31  2018      3    5          0   14.0    3.0
#
#                      lag_3  lag_4  lag_5  ...  lag_16  lag_17  lag_18  lag_19  \
# datetime                                  ...
# 2018-03-05 04:00:00  176.0   86.0   68.0  ...    30.0    41.0    19.0    39.0
# 2018-03-05 05:00:00   32.0  176.0   86.0  ...    30.0    30.0    41.0    19.0
# 2018-03-05 06:00:00   51.0   32.0  176.0  ...    56.0    30.0    30.0    41.0
# 2018-03-05 07:00:00   34.0   51.0   32.0  ...    58.0    56.0    30.0    30.0
# 2018-03-05 08:00:00   16.0   34.0   51.0  ...    64.0    58.0    56.0    30.0
#
#                      lag_20  lag_21  lag_22  lag_23  lag_24  rolling_mean
# datetime
# 2018-03-05 04:00:00    39.0    12.0    11.0    22.0    27.0         56.46
# 2018-03-05 05:00:00    39.0    39.0    12.0    11.0    22.0         55.56
# 2018-03-05 06:00:00    19.0    39.0    39.0    12.0    11.0         54.87
# 2018-03-05 07:00:00    41.0    19.0    39.0    39.0    12.0         54.19
# 2018-03-05 08:00:00    30.0    41.0    19.0    39.0    39.0         53.67
#
# [5 rows x 30 columns]

# %%
#Поделим данные на фичи и таргеты,  а также на train и test:
train, test = train_test_split(df, shuffle=False, test_size=0.1, random_state = RS)

features_train = train.drop(['num_orders'], axis=1)
target_train = train['num_orders']
features_test = test.drop(['num_orders'], axis=1)
target_test = test['num_orders']

print(features_train.shape[0]/df.shape[0], features_test.shape[0]/df.shape[0])
print(target_train.shape[0]/df.shape[0], target_test.shape[0]/df.shape[0])
# Out:
# 0.8999073215940686 0.10009267840593142
# 0.8999073215940686 0.10009267840593142

# %%
# создадим RMSE score 
def RMSE(target, predict):
    return (mean_squared_error(target, predict))**0.5

RMSE_score = make_scorer(RMSE, greater_is_better=False)

# %% [markdown]
# **Линейная регрессия**

# %%
# %%time
r_cv = TimeSeriesSplit(n_splits=3).split(features_train)
reg = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
reg.fit(features_train, target_train)
r_cv_score = pd.Series(cross_val_score(reg,features_train,target_train,scoring=RMSE_score,cv=r_cv)).mean()*(-1)
print('RMSE линейной регрессии на кросс-валидации:', r_cv_score)
# Out:
# RMSE линейной регрессии на кросс-валидации: 28.275898753655373
# CPU times: user 287 ms, sys: 333 ms, total: 619 ms
# Wall time: 561 ms

# %% [markdown]
# **Random forest**

# %%
# %%time
f_cv = TimeSeriesSplit(n_splits=3).split(features_train)
rf = RandomForestRegressor()
#Определяю словарь с набором параметров
f_params = { 'n_estimators': range(5, 30, 5),
                     'max_depth': range(1, 15, 2),
                     'min_samples_leaf': range(1,5),
                     'min_samples_split': range(2,8,2) }

#Применяю GridSearchCV с кросс-валидацией
f_grid = GridSearchCV(rf, f_params, scoring=RMSE_score, cv=f_cv)
f_grid.fit(features_train, target_train)
# Out:
# CPU times: user 4min 7s, sys: 637 ms, total: 4min 8s
# Wall time: 4min 8s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x7f3967a7c200>,
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': range(1, 15, 2),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(2, 8, 2),
#                          'n_estimators': range(5, 30, 5)},
#              scoring=make_scorer(RMSE, greater_is_better=False))

# %%
# %%time

f_params = f_grid.best_params_
f_score = f_grid.score(features_train, target_train) * (-1)
print(f_params)
print(f_score)
# Out:
# {'max_depth': 13, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 25}
# 13.233039167199875
# CPU times: user 22.3 ms, sys: 0 ns, total: 22.3 ms
# Wall time: 39 ms

# %% [markdown]
# **CatBoost**

# %%
# %%time

c_cv = TimeSeriesSplit(n_splits=3).split(features_train)
cat = cb.CatBoostRegressor()
#Определяю словарь с набором параметров
c_params = {'learning_rate': [0.03, 0.1, 0.2],
                'depth': [4, 6, 10]
               }
c_grid = GridSearchCV(cat, c_params, scoring=RMSE_score, cv=c_cv)
c_grid.fit(features_train, target_train, verbose=100)
# Out:
# 0:	learn: 28.8547429	total: 54.8ms	remaining: 54.8s
# 100:	learn: 18.1994024	total: 204ms	remaining: 1.82s
# 200:	learn: 16.2825116	total: 356ms	remaining: 1.41s
# 300:	learn: 15.0781771	total: 509ms	remaining: 1.18s
# 400:	learn: 13.9105862	total: 662ms	remaining: 989ms
# 500:	learn: 12.8555891	total: 814ms	remaining: 810ms
# 600:	learn: 11.9949258	total: 978ms	remaining: 649ms
# 700:	learn: 11.1144727	total: 1.13s	remaining: 481ms
# 800:	learn: 10.4435977	total: 1.28s	remaining: 318ms
# 900:	learn: 9.8094890	total: 1.43s	remaining: 157ms
# 999:	learn: 9.2428678	total: 1.58s	remaining: 0us
# 0:	learn: 31.8971050	total: 2.65ms	remaining: 2.65s
# 100:	learn: 20.4293611	total: 189ms	remaining: 1.68s
# 200:	learn: 18.7120777	total: 377ms	remaining: 1.5s
# 300:	learn: 17.5993542	total: 585ms	remaining: 1.36s
# 400:	learn: 16.7013235	total: 781ms	remaining: 1.17s
# 500:	learn: 15.9508179	total: 1.03s	remaining: 1.03s
# 600:	learn: 15.2953652	total: 1.25s	remaining: 832ms
# 700:	learn: 14.6979112	total: 1.45s	remaining: 617ms
# 800:	learn: 14.1806022	total: 1.64s	remaining: 408ms
# 900:	learn: 13.6802896	total: 1.87s	remaining: 206ms
# 999:	learn: 13.2310163	total: 2.09s	remaining: 0us
# 0:	learn: 33.4508000	total: 3.08ms	remaining: 3.07s
# 100:	learn: 22.0191622	total: 257ms	remaining: 2.29s
# 200:	learn: 20.5770815	total: 486ms	remaining: 1.93s
# 300:	learn: 19.6632694	total: 727ms	remaining: 1.69s
# 400:	learn: 18.9248583	total: 951ms	remaining: 1.42s
# 500:	learn: 18.2213967	total: 1.2s	remaining: 1.2s
# 600:	learn: 17.5701036	total: 1.42s	remaining: 946ms
# 700:	learn: 16.9927482	total: 1.65s	remaining: 706ms
# 800:	learn: 16.4465366	total: 1.93s	remaining: 479ms
# 900:	learn: 15.9766358	total: 2.18s	remaining: 239ms
# 999:	learn: 15.5604942	total: 2.42s	remaining: 0us
# 0:	learn: 28.0431361	total: 1.69ms	remaining: 1.69s
# 100:	learn: 14.7042441	total: 180ms	remaining: 1.6s
# 200:	learn: 11.3103925	total: 355ms	remaining: 1.41s
# 300:	learn: 9.1050503	total: 552ms	remaining: 1.28s
# 400:	learn: 7.3650985	total: 732ms	remaining: 1.09s
# 500:	learn: 6.0882870	total: 884ms	remaining: 881ms
# 600:	learn: 5.0962948	total: 1.04s	remaining: 690ms
# 700:	learn: 4.3044763	total: 1.2s	remaining: 511ms
# 800:	learn: 3.6693145	total: 1.37s	remaining: 341ms
# 900:	learn: 3.1079321	total: 1.55s	remaining: 170ms
# 999:	learn: 2.6315605	total: 1.71s	remaining: 0us
# 0:	learn: 30.9635062	total: 2.08ms	remaining: 2.07s
# 100:	learn: 17.5156423	total: 214ms	remaining: 1.9s
# 200:	learn: 15.2231702	total: 428ms	remaining: 1.7s
# 300:	learn: 13.3528824	total: 625ms	remaining: 1.45s
# 400:	learn: 11.9241890	total: 824ms	remaining: 1.23s
# 500:	learn: 10.8162815	total: 1.03s	remaining: 1.03s
# 600:	learn: 9.7203066	total: 1.23s	remaining: 814ms
# 700:	learn: 8.7470777	total: 1.43s	remaining: 609ms
# 800:	learn: 7.9684514	total: 1.62s	remaining: 403ms
# 900:	learn: 7.2489772	total: 1.83s	remaining: 201ms
# 999:	learn: 6.6432413	total: 2.02s	remaining: 0us
# 0:	learn: 32.4406722	total: 2.63ms	remaining: 2.62s
# 100:	learn: 19.3655544	total: 219ms	remaining: 1.95s
# 200:	learn: 17.2246758	total: 425ms	remaining: 1.69s
# 300:	learn: 15.5718615	total: 630ms	remaining: 1.46s
# 400:	learn: 14.3569928	total: 837ms	remaining: 1.25s
# 500:	learn: 13.1629561	total: 1.05s	remaining: 1.04s
# 600:	learn: 12.2475565	total: 1.26s	remaining: 839ms
# 700:	learn: 11.4123901	total: 1.47s	remaining: 628ms
# 800:	learn: 10.6866717	total: 1.69s	remaining: 420ms
# 900:	learn: 10.0047007	total: 1.91s	remaining: 209ms
# 999:	learn: 9.3576478	total: 2.12s	remaining: 0us
# 0:	learn: 26.9461258	total: 1.58ms	remaining: 1.58s
# 100:	learn: 11.6036854	total: 153ms	remaining: 1.36s
# 200:	learn: 7.8705879	total: 306ms	remaining: 1.22s
# 300:	learn: 5.3926495	total: 454ms	remaining: 1.05s
# 400:	learn: 3.9132401	total: 609ms	remaining: 909ms
# 500:	learn: 2.7546737	total: 764ms	remaining: 761ms
# 600:	learn: 2.1152709	total: 935ms	remaining: 621ms
# 700:	learn: 1.5632625	total: 1.15s	remaining: 492ms
# 800:	learn: 1.1858744	total: 1.31s	remaining: 327ms
# 900:	learn: 0.8860034	total: 1.47s	remaining: 161ms
# 999:	learn: 0.6787319	total: 1.61s	remaining: 0us
# 0:	learn: 29.7038118	total: 2.03ms	remaining: 2.03s
# 100:	learn: 14.9653389	total: 187ms	remaining: 1.66s
# 200:	learn: 11.9037153	total: 375ms	remaining: 1.49s
# 300:	learn: 9.8113904	total: 558ms	remaining: 1.3s
# 400:	learn: 8.0563130	total: 748ms	remaining: 1.12s
# 500:	learn: 6.6763921	total: 969ms	remaining: 965ms
# 600:	learn: 5.5149170	total: 1.16s	remaining: 770ms
# 700:	learn: 4.6473982	total: 1.35s	remaining: 577ms
# 800:	learn: 3.9229215	total: 1.55s	remaining: 385ms
# 900:	learn: 3.3244823	total: 1.75s	remaining: 192ms
# 999:	learn: 2.8121267	total: 1.96s	remaining: 0us
# 0:	learn: 31.0784704	total: 3.27ms	remaining: 3.27s
# 100:	learn: 17.4769483	total: 228ms	remaining: 2.03s
# 200:	learn: 14.4819740	total: 444ms	remaining: 1.76s
# 300:	learn: 12.3439363	total: 684ms	remaining: 1.59s
# 400:	learn: 10.7801093	total: 899ms	remaining: 1.34s
# 500:	learn: 9.4051870	total: 1.11s	remaining: 1.11s
# 600:	learn: 8.3020395	total: 1.32s	remaining: 880ms
# 700:	learn: 7.3220305	total: 1.54s	remaining: 656ms
# 800:	learn: 6.4930295	total: 1.76s	remaining: 438ms
# 900:	learn: 5.7789185	total: 1.98s	remaining: 218ms
# 999:	learn: 5.1948083	total: 2.19s	remaining: 0us
# 0:	learn: 28.8692339	total: 5.5ms	remaining: 5.5s
# 100:	learn: 16.7136586	total: 365ms	remaining: 3.25s
# 200:	learn: 14.2970699	total: 749ms	remaining: 2.98s
# 300:	learn: 12.4462795	total: 1.13s	remaining: 2.62s
# 400:	learn: 10.8796875	total: 1.51s	remaining: 2.26s
# 500:	learn: 9.5375300	total: 1.88s	remaining: 1.88s
# 600:	learn: 8.4057475	total: 2.24s	remaining: 1.49s
# 700:	learn: 7.5171566	total: 2.62s	remaining: 1.12s
# 800:	learn: 6.7444672	total: 3.03s	remaining: 753ms
# 900:	learn: 6.0339181	total: 3.38s	remaining: 371ms
# 999:	learn: 5.3753946	total: 3.73s	remaining: 0us
# 0:	learn: 31.8502828	total: 5.7ms	remaining: 5.69s
# 100:	learn: 19.1669172	total: 450ms	remaining: 4s
# 200:	learn: 16.9652748	total: 911ms	remaining: 3.62s
# 300:	learn: 15.4627510	total: 1.35s	remaining: 3.13s
# 400:	learn: 14.1844472	total: 1.77s	remaining: 2.65s
# 500:	learn: 13.1272129	total: 2.22s	remaining: 2.21s
# 600:	learn: 12.2400736	total: 2.67s	remaining: 1.77s
# 700:	learn: 11.4887813	total: 3.13s	remaining: 1.34s
# 800:	learn: 10.7534155	total: 3.56s	remaining: 884ms
# 900:	learn: 10.0477626	total: 4.01s	remaining: 440ms
# 999:	learn: 9.4128331	total: 4.45s	remaining: 0us
# 0:	learn: 33.4448983	total: 5.98ms	remaining: 5.98s
# 100:	learn: 20.8562295	total: 507ms	remaining: 4.51s
# 200:	learn: 18.9758353	total: 1.03s	remaining: 4.09s
# 300:	learn: 17.7538683	total: 1.51s	remaining: 3.51s
# 400:	learn: 16.6181561	total: 1.98s	remaining: 2.96s
# 500:	learn: 15.5057335	total: 2.45s	remaining: 2.44s
# 600:	learn: 14.5675434	total: 3s	remaining: 1.99s
# 700:	learn: 13.8243584	total: 3.48s	remaining: 1.48s
# 800:	learn: 13.1078067	total: 3.96s	remaining: 984ms
# 900:	learn: 12.4175604	total: 4.46s	remaining: 490ms
# 999:	learn: 11.8104266	total: 4.96s	remaining: 0us
# 0:	learn: 28.0891152	total: 4.1ms	remaining: 4.09s
# 100:	learn: 12.0159337	total: 383ms	remaining: 3.4s
# 200:	learn: 7.7316105	total: 743ms	remaining: 2.95s
# 300:	learn: 5.3371702	total: 1.11s	remaining: 2.57s
# 400:	learn: 3.6935472	total: 1.48s	remaining: 2.21s
# 500:	learn: 2.5487576	total: 1.86s	remaining: 1.85s
# 600:	learn: 1.8917093	total: 2.22s	remaining: 1.48s
# 700:	learn: 1.3943054	total: 2.6s	remaining: 1.11s
# 800:	learn: 1.0351919	total: 2.97s	remaining: 738ms
# 900:	learn: 0.7692481	total: 3.32s	remaining: 365ms
# 999:	learn: 0.5648580	total: 3.67s	remaining: 0us
# 0:	learn: 30.8060852	total: 4.67ms	remaining: 4.67s
# 100:	learn: 15.0770687	total: 452ms	remaining: 4.02s
# 200:	learn: 11.7572393	total: 884ms	remaining: 3.51s
# 300:	learn: 9.6488328	total: 1.31s	remaining: 3.05s
# 400:	learn: 7.6168260	total: 1.76s	remaining: 2.62s
# 500:	learn: 6.1972524	total: 2.2s	remaining: 2.19s
# 600:	learn: 4.9987561	total: 2.68s	remaining: 1.78s
# 700:	learn: 4.0929656	total: 3.11s	remaining: 1.33s
# 800:	learn: 3.4486613	total: 3.54s	remaining: 880ms
# 900:	learn: 2.8523843	total: 3.99s	remaining: 438ms
# 999:	learn: 2.3980963	total: 4.43s	remaining: 0us
# 0:	learn: 32.4200909	total: 5.33ms	remaining: 5.32s
# 100:	learn: 17.1714242	total: 511ms	remaining: 4.55s
# 200:	learn: 14.0283739	total: 1.02s	remaining: 4.07s
# 300:	learn: 11.7840734	total: 1.51s	remaining: 3.51s
# 400:	learn: 9.9582603	total: 2.01s	remaining: 3s
# 500:	learn: 8.5639468	total: 2.49s	remaining: 2.48s
# 600:	learn: 7.4369242	total: 2.97s	remaining: 1.97s
# 700:	learn: 6.4845858	total: 3.45s	remaining: 1.47s
# 800:	learn: 5.5989653	total: 3.94s	remaining: 979ms
# 900:	learn: 4.9209332	total: 4.44s	remaining: 488ms
# 999:	learn: 4.2872083	total: 4.99s	remaining: 0us
# 0:	learn: 27.0307801	total: 3.91ms	remaining: 3.9s
# 100:	learn: 7.4456430	total: 356ms	remaining: 3.17s
# 200:	learn: 3.6130418	total: 711ms	remaining: 2.83s
# 300:	learn: 1.9342398	total: 1.07s	remaining: 2.49s
# 400:	learn: 1.0889913	total: 1.5s	remaining: 2.24s
# 500:	learn: 0.5764671	total: 1.86s	remaining: 1.85s
# 600:	learn: 0.3023099	total: 2.21s	remaining: 1.47s
# 700:	learn: 0.1609952	total: 2.56s	remaining: 1.09s
# 800:	learn: 0.0805689	total: 2.94s	remaining: 730ms
# 900:	learn: 0.0442068	total: 3.3s	remaining: 363ms
# 999:	learn: 0.0236857	total: 3.65s	remaining: 0us
# 0:	learn: 29.3855918	total: 5ms	remaining: 4.99s
# 100:	learn: 11.5483423	total: 446ms	remaining: 3.97s
# 200:	learn: 7.4990882	total: 896ms	remaining: 3.56s
# 300:	learn: 5.1682411	total: 1.35s	remaining: 3.14s
# 400:	learn: 3.4304114	total: 1.8s	remaining: 2.69s
# 500:	learn: 2.3536936	total: 2.25s	remaining: 2.24s
# 600:	learn: 1.6560956	total: 2.69s	remaining: 1.79s
# 700:	learn: 1.1504491	total: 3.15s	remaining: 1.34s
# 800:	learn: 0.8160929	total: 3.6s	remaining: 893ms
# 900:	learn: 0.5729279	total: 4.04s	remaining: 443ms
# 999:	learn: 0.4096056	total: 4.48s	remaining: 0us
# 0:	learn: 31.0346163	total: 5.19ms	remaining: 5.19s
# 100:	learn: 13.9602495	total: 496ms	remaining: 4.41s
# 200:	learn: 10.0915242	total: 989ms	remaining: 3.93s
# 300:	learn: 7.6436601	total: 1.54s	remaining: 3.57s
# 400:	learn: 5.8601112	total: 2s	remaining: 2.99s
# 500:	learn: 4.5065198	total: 2.49s	remaining: 2.48s
# 600:	learn: 3.5991280	total: 3.01s	remaining: 2s
# 700:	learn: 2.7967011	total: 3.5s	remaining: 1.49s
# 800:	learn: 2.1937266	total: 4s	remaining: 993ms
# 900:	learn: 1.7019368	total: 4.5s	remaining: 495ms
# 999:	learn: 1.3431231	total: 5s	remaining: 0us
# 0:	learn: 28.8721228	total: 35.2ms	remaining: 35.1s
# 100:	learn: 13.6958438	total: 3.36s	remaining: 29.9s
# 200:	learn: 9.2764498	total: 6.72s	remaining: 26.7s
# 300:	learn: 6.8469179	total: 10.1s	remaining: 23.5s
# 400:	learn: 4.9259611	total: 13.5s	remaining: 20.2s
# 500:	learn: 3.6149732	total: 17s	remaining: 17s
# 600:	learn: 2.7301854	total: 20.7s	remaining: 13.7s
# 700:	learn: 1.9982488	total: 24.4s	remaining: 10.4s
# 800:	learn: 1.4689693	total: 27.9s	remaining: 6.94s
# 900:	learn: 1.1139642	total: 31.4s	remaining: 3.45s
# 999:	learn: 0.8386622	total: 34.8s	remaining: 0us
# 0:	learn: 31.8588853	total: 54.4ms	remaining: 54.3s
# 100:	learn: 15.8601242	total: 4.19s	remaining: 37.3s
# 200:	learn: 11.9573006	total: 8.3s	remaining: 33s
# 300:	learn: 9.7345824	total: 12.4s	remaining: 28.9s
# 400:	learn: 7.8823242	total: 16.6s	remaining: 24.8s
# 500:	learn: 6.4757058	total: 20.8s	remaining: 20.8s
# 600:	learn: 5.4355569	total: 25s	remaining: 16.6s
# 700:	learn: 4.5033288	total: 29.3s	remaining: 12.5s
# 800:	learn: 3.7032701	total: 33.4s	remaining: 8.3s
# 900:	learn: 3.0805388	total: 37.5s	remaining: 4.12s
# 999:	learn: 2.5695429	total: 41.6s	remaining: 0us
# 0:	learn: 33.4523822	total: 44ms	remaining: 44s
# 100:	learn: 17.9335589	total: 4.53s	remaining: 40.4s
# 200:	learn: 14.3093725	total: 9.16s	remaining: 36.4s
# 300:	learn: 12.0911423	total: 13.7s	remaining: 31.9s
# 400:	learn: 10.2484056	total: 18.2s	remaining: 27.3s
# 500:	learn: 8.6319248	total: 22.8s	remaining: 22.7s
# 600:	learn: 7.3227327	total: 27.4s	remaining: 18.2s
# 700:	learn: 6.2456052	total: 31.9s	remaining: 13.6s
# 800:	learn: 5.4748778	total: 36.5s	remaining: 9.06s
# 900:	learn: 4.8139093	total: 41.1s	remaining: 4.51s
# 999:	learn: 4.1959144	total: 45.6s	remaining: 0us
# 0:	learn: 28.0937712	total: 34.1ms	remaining: 34.1s
# 100:	learn: 5.7656087	total: 3.35s	remaining: 29.8s
# 200:	learn: 2.0349299	total: 6.72s	remaining: 26.7s
# 300:	learn: 0.8154661	total: 10.1s	remaining: 23.6s
# 400:	learn: 0.3260525	total: 13.4s	remaining: 20.1s
# 500:	learn: 0.1375295	total: 16.8s	remaining: 16.8s
# 600:	learn: 0.0583440	total: 20.3s	remaining: 13.5s
# 700:	learn: 0.0268782	total: 23.8s	remaining: 10.1s
# 800:	learn: 0.0121420	total: 27.3s	remaining: 6.78s
# 900:	learn: 0.0060629	total: 30.8s	remaining: 3.39s
# 999:	learn: 0.0025289	total: 34.3s	remaining: 0us
# 0:	learn: 30.8284474	total: 46.7ms	remaining: 46.7s
# 100:	learn: 9.1077319	total: 4.5s	remaining: 40.1s
# 200:	learn: 4.7576848	total: 8.71s	remaining: 34.6s
# 300:	learn: 2.6720812	total: 12.9s	remaining: 30.1s
# 400:	learn: 1.5201075	total: 17.3s	remaining: 25.9s
# 500:	learn: 0.7783981	total: 21.4s	remaining: 21.4s
# 600:	learn: 0.4273617	total: 25.6s	remaining: 17s
# 700:	learn: 0.2314672	total: 29.7s	remaining: 12.7s
# 800:	learn: 0.1198979	total: 33.9s	remaining: 8.42s
# 900:	learn: 0.0680228	total: 38s	remaining: 4.18s
# 999:	learn: 0.0388074	total: 42.1s	remaining: 0us
# 0:	learn: 32.4406582	total: 46.2ms	remaining: 46.1s
# 100:	learn: 11.5163840	total: 4.71s	remaining: 41.9s
# 200:	learn: 6.7510401	total: 9.21s	remaining: 36.6s
# 300:	learn: 4.1994347	total: 13.8s	remaining: 32s
# 400:	learn: 2.7994551	total: 18.4s	remaining: 27.5s
# 500:	learn: 1.7400346	total: 23.1s	remaining: 23.1s
# 600:	learn: 1.0676327	total: 27.8s	remaining: 18.4s
# 700:	learn: 0.6640808	total: 32.5s	remaining: 13.8s
# 800:	learn: 0.4065614	total: 37.1s	remaining: 9.21s
# 900:	learn: 0.2463052	total: 41.9s	remaining: 4.6s
# 999:	learn: 0.1603032	total: 46.5s	remaining: 0us
# 0:	learn: 27.0248964	total: 32.6ms	remaining: 32.6s
# 100:	learn: 2.1297943	total: 3.47s	remaining: 30.9s
# 200:	learn: 0.3515537	total: 6.68s	remaining: 26.5s
# 300:	learn: 0.0585628	total: 10s	remaining: 23.3s
# 400:	learn: 0.0109578	total: 13.4s	remaining: 20.1s
# 500:	learn: 0.0022687	total: 16.9s	remaining: 16.8s
# 600:	learn: 0.0004616	total: 20.2s	remaining: 13.4s
# 700:	learn: 0.0000843	total: 23.6s	remaining: 10.1s
# 800:	learn: 0.0000146	total: 26.9s	remaining: 6.69s
# 900:	learn: 0.0000028	total: 30.3s	remaining: 3.33s
# 999:	learn: 0.0000005	total: 33.7s	remaining: 0us
# 0:	learn: 29.4106775	total: 41.3ms	remaining: 41.3s
# 100:	learn: 4.5912528	total: 4.27s	remaining: 38s
# 200:	learn: 1.3387878	total: 8.5s	remaining: 33.8s
# 300:	learn: 0.4436994	total: 12.7s	remaining: 29.5s
# 400:	learn: 0.1442807	total: 16.8s	remaining: 25.1s
# 500:	learn: 0.0465612	total: 21s	remaining: 20.9s
# 600:	learn: 0.0145424	total: 25.2s	remaining: 16.7s
# 700:	learn: 0.0046571	total: 29.4s	remaining: 12.5s
# 800:	learn: 0.0013829	total: 33.6s	remaining: 8.34s
# 900:	learn: 0.0004719	total: 37.8s	remaining: 4.15s
# 999:	learn: 0.0001696	total: 41.9s	remaining: 0us
# 0:	learn: 31.0621759	total: 48.1ms	remaining: 48.1s
# 100:	learn: 6.6469550	total: 4.55s	remaining: 40.5s
# 200:	learn: 2.6061052	total: 9.12s	remaining: 36.2s
# 300:	learn: 1.0839639	total: 13.7s	remaining: 31.9s
# 400:	learn: 0.4309121	total: 18.4s	remaining: 27.4s
# 500:	learn: 0.1813848	total: 23s	remaining: 22.9s
# 600:	learn: 0.0730789	total: 27.7s	remaining: 18.4s
# 700:	learn: 0.0309832	total: 32.3s	remaining: 13.8s
# 800:	learn: 0.0131396	total: 37s	remaining: 9.19s
# 900:	learn: 0.0058434	total: 41.7s	remaining: 4.58s
# 999:	learn: 0.0025904	total: 46.7s	remaining: 0us
# 0:	learn: 38.1916728	total: 7.17ms	remaining: 7.16s
# 100:	learn: 23.8567632	total: 660ms	remaining: 5.87s
# 200:	learn: 22.1526448	total: 1.31s	remaining: 5.2s
# 300:	learn: 20.7671827	total: 1.99s	remaining: 4.63s
# 400:	learn: 19.5575288	total: 2.61s	remaining: 3.9s
# 500:	learn: 18.3750922	total: 3.23s	remaining: 3.22s
# 600:	learn: 17.3629822	total: 3.87s	remaining: 2.57s
# 700:	learn: 16.5080427	total: 4.5s	remaining: 1.92s
# 800:	learn: 15.6862726	total: 5.12s	remaining: 1.27s
# 900:	learn: 15.0062004	total: 5.85s	remaining: 643ms
# 999:	learn: 14.3298755	total: 6.51s	remaining: 0us
# CPU times: user 7min 13s, sys: 3.14 s, total: 7min 16s
# Wall time: 7min 41s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x7f3967c80e40>,
#              estimator=<catboost.core.CatBoostRegressor object at 0x7f3967d451f0>,
#              param_grid={'depth': [4, 6, 10],
#                          'learning_rate': [0.03, 0.1, 0.2]},
#              scoring=make_scorer(RMSE, greater_is_better=False))

# %%
# %%time

c_params = c_grid.best_params_
c_score = c_grid.score(features_train, target_train) * (-1)
print(c_params)
print(c_score)
# Out:
# {'depth': 6, 'learning_rate': 0.03}
# 14.329875490541367
# CPU times: user 5.6 ms, sys: 3.95 ms, total: 9.54 ms
# Wall time: 7.2 ms

# %% [markdown]
# ## Тестирование

# %%
lin_array =    [r_cv_score]
forest_array = [f_score]
cat_array =    [c_score]

rezult={'Линейная регрессия':np.array(lin_array), 'Случайный лес':np.array(forest_array), 
        'CatBoost':np.array(cat_array)}
rezult_df=pd.DataFrame(rezult,index=['rmse'])

# %%
rezult_df
# Out:
#       Линейная регрессия  Случайный лес   CatBoost
# rmse           28.275899      13.233039  14.329875

# %% [markdown]
# **Лучшей моделью оказался случайный лес**

# %%
# %%time

#Протестируем модель на оптимальных гиперпараметрах

forest_model = RandomForestRegressor(random_state=RS,
                                     max_depth=f_params['max_depth'],
                                     min_samples_leaf = f_params['min_samples_leaf'],
                                     min_samples_split = f_params['min_samples_split'],
                                     n_estimators = f_params['n_estimators'])

forest_model.fit(features_train, target_train)
forest_model_predictions = forest_model.predict(features_test)
forest_RMSE = round(RMSE(target_test, forest_model_predictions), 3)
print('RMSE модели Случайного леса на тесте:', forest_RMSE)
# Out:
# RMSE модели Случайного леса на тесте: 43.418
# CPU times: user 1.08 s, sys: 0 ns, total: 1.08 s
# Wall time: 1.08 s

# %%
# %%time

# #Обучаю модель на оптимальных гиперпараметрах
# model_cat = cb.CatBoostRegressor(learning_rate=c_params['learning_rate'],
#                                 depth=c_params['depth'])

# model_cat.fit(features_train, target_train, verbose=100)
# model_cat_pred = model_cat.predict(features_test)

# #Определяю метрику RMSE
# cat_RMSE = round(RMSE(target_test, model_cat_pred), 3)
# print('RMSE модели CatBoostRegressor:', cat_RMSE)

# %%
# %%time
forest_model.fit(features_train, target_train)
f_imp = pd.Series(forest_model.feature_importances_, features_train.columns)
# Out:
# CPU times: user 1.06 s, sys: 4.01 ms, total: 1.06 s
# Wall time: 1.06 s

# %%
fig, ax = plt.subplots(figsize=(10,6))
f_imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность, %')
fig.tight_layout()

# %%
pred = pd.Series(forest_model_predictions)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax= pred.plot.bar()
target_test.plot.bar(ax=ax, )
ax.set_title("Тест и предикт")
ax.set_ylabel('Заказы')
fig.tight_layout()

# %% [markdown]
# **Вывод**
#
# Лучшей моделью оказался случайный лес. Значение метрики RMSE на тестовой выборке меньше 48.

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
